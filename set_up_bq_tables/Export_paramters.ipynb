# %%
# %%bash
# export PROJECT_ID="prj-ai-dev-qic"

# export BQ_SOURCES='[

# # {"project":"prj-ai-dev-qic","dataset":"qic_asset_amc"}, 
# # {"project":"prj-ai-dev-qic","dataset":"qic_finance"}, 
# # {"project":"prj-ai-dev-qic","dataset":"qic_hr"}, 
# # {"project":"prj-ai-dev-qic","dataset":"qic_vgs"},
# {"project":"prj-ai-dev-qic","dataset":"qic_qbrain_prod"}]'



# # export BQ_SOURCES='[ 
# # {"project":"prj-ai-dev-qic","dataset":"qic_hr"}, 
# # {"project":"prj-ai-dev-qic","dataset":"qic_dev_payments"}]'

# export BQ_TABLES='[
# "prj-ai-dev-qic.qic_qbrain_prod.ride_queue",
# "prj-ai-dev-qic.qic_qbrain_prod.sfq_rid_thr_manual_data",
# ]'

# # export BQ_TABLES= ""

# # export RECONCILIATION_MODE="INCREMENTAL"


# # export GCS_BUCKET="qiddiya-metadata-rag"
# export GCS_BUCKET="qbrain-staging"
# export GCS_PREFIX="bq_schema_cards"

# export ENABLE_LLM="true"
# export VERTEX_PROJECT="prj-ai-dev-qic"
# export VERTEX_REGION="europe-west1"
# export GEMINI_MODEL="gemini-2.5-pro"

# # Vertex Search datastore refresh
# export REFRESH_SEARCH="true"
# export SEARCH_LOCATION=us
# export DATA_STORE_ID="qbrain-metadata-search_1771244901364"
# export DATA_SCHEMA="document"
# export RECONCILIATION_MODE="INCREMENTAL"

# # pip install --upgrade setuptools wheel && pip install -r requirements.txt

# # python main.py
# # python main_toolbox.py

# %%
import os

os.environ["PROJECT_ID"]    = "prj-ai-dev-qic"

# os.environ["BQ_TABLES"] = (
#     '["prj-ai-dev-qic.qic_qbrain_prod.ride_queue",'
#     ' "prj-ai-dev-qic.qic_qbrain_prod.sfq_rid_thr_manual_data_v1",'
#     ' "prj-ai-dev-qic.qic_qbrain_prod.visitor_filterd",'
#     ' "prj-ai-dev-qic.qic_qbrain_prod.finance_group",'
#     ' "prj-ai-dev-qic.qic_qbrain_prod.arrival_time",'
#     ' "prj-ai-dev-qic.qic_qbrain_prod.sfq_dai_rev_full_revenue_summary_v1",'
#     ' "prj-ai-dev-qic.qic_qbrain_prod.sfq_dai_rev_rep_f_b_summary_v1",'
#     ' "prj-ai-dev-qic.qic_qbrain_prod.sfq_dai_rev_rep_retail_summary_v1",'
#     ' "prj-ai-dev-qic.qic_qbrain_prod.asp_nps_csa_man_data",'
#     ' "prj-ai-dev-qic.qic_qbrain_prod.asp_nps_csa_man_daily_data",'
#     ' "prj-ai-dev-qic.qic_qbrain_prod.sfq_att_manual_data_v1",'
#     ' "prj-ai-dev-qic.qic_qbrain_prod".sfq_dow_downtime_log_v1",'
#     ' "prj-ai-dev-qic.qic_qbrain_prod.sfq_dow_operating_hours_v1",'
#     ' "prj-ai-dev-qic.qic_qbrain_prod.sfq_dow_202_dec_operating_hours_2025_v1"]'
# )
os.environ["BQ_SOURCES"]    = ""   # explicitly cleared
os.environ["GCS_BUCKET"]    = "qbrain-staging"
os.environ["GCS_PREFIX"]    = "bq_schema_cards"
os.environ["ENABLE_LLM"]    = "true"
os.environ["VERTEX_PROJECT"]= "prj-ai-dev-qic"
os.environ["VERTEX_REGION"] = "europe-west1"
os.environ["GEMINI_MODEL"]  = "gemini-2.5-pro"
os.environ["REFRESH_SEARCH"]= "true"
os.environ["SEARCH_LOCATION"]= "eu"
os.environ["DATA_STORE_ID"] = "qbrain-metadata-search_1771244901364"
os.environ["DATA_SCHEMA"]   = "document"
os.environ["RECONCILIATION_MODE"] = "INCREMENTAL"

# %%
import os, json, importlib


os.environ["BQ_TABLES"] = json.dumps([
    "prj-ai-dev-qic.qic_qbrain_prod.ride_queue",
    "prj-ai-dev-qic.qic_qbrain_prod.sfq_rid_thr_manual_data",
    "prj-ai-dev-qic.qic_qbrain_prod.visitor_filterd",
    "prj-ai-dev-qic.qic_qbrain_prod.finance_group",
    "prj-ai-dev-qic.qic_qbrain_prod.arrival_time",
    "prj-ai-dev-qic.qic_qbrain_prod.sfq_dai_rev_full_revenue_summary",
    "prj-ai-dev-qic.qic_qbrain_prod.sfq_dai_rev_rep_f_b_summary",
    "prj-ai-dev-qic.qic_qbrain_prod.sfq_dai_rev_rep_retail_summary",
    "prj-ai-dev-qic.qic_qbrain_prod.asp_nps_csa_man_data",
    "prj-ai-dev-qic.qic_qbrain_prod.asp_nps_csa_man_daily_data",
    "prj-ai-dev-qic.qic_qbrain_prod.sfq_att_manual_data",
    "prj-ai-dev-qic.qic_qbrain_prod.sfq_dow_downtime_log",
    "prj-ai-dev-qic.qic_qbrain_prod.sfq_dow_operating_hours",
    "prj-ai-dev-qic.qic_qbrain_prod.sfq_dow_202_dec_operating_hours_2025",
    "prj-ai-dev-qic.qic_qbrain_prod.l1_city_ops_citystaffdata_sharepoint",
    "prj-ai-dev-qic.qic_qbrain_prod.l1_city_ops_health_safety_sharepoint",
    "prj-ai-dev-qic.qic_qbrain_prod.l1_city_ops_parking_utilization_sharepoint",
    "prj-ai-dev-qic.qic_qbrain_prod.l1_city_ops_security_responsetime_sharepoint",
    "prj-ai-dev-qic.qic_qbrain_prod.l1_city_ops_unloadentry_sharepoint",
    "prj-ai-dev-qic.qic_qbrain_prod.l1_city_ops_executivesummary_sharepoint",
    "prj-ai-dev-qic.qic_qbrain_prod.l1_city_ops_exitguests_sharepoint",
    "prj-ai-dev-qic.qic_qbrain_prod.l1_city_ops_extrasalesexpected_sharepoint",
    "prj-ai-dev-qic.qic_qbrain_prod.l1_city_ops_forcastvisitor_sharepoint",
    "prj-ai-dev-qic.qic_qbrain_prod.l1_city_ops_weeklysentiment_sharepoint",
    "prj-ai-dev-qic.qic_qbrain_prod.l1_ccu_ride_status_spms",
    "prj-ai-dev-qic.qic_qbrain_prod.l1_ccu_tickets_vgs",
    "prj-ai-dev-qic.qic_qbrain_prod.l1_ccu_weather_spms",
    "prj-ai-dev-qic.qic_qbrain_prod.l1_entry_exit_vgs",
    
])

import main_toolbox
importlib.reload(main_toolbox)
main_toolbox.main()
# Out:
# /opt/conda/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform_v1beta1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform_v1beta1 past that date.
#   warnings.warn(message, FutureWarning)
# /opt/conda/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform_v1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform_v1 past that date.
#   warnings.warn(message, FutureWarning)
# ...

# %%
# # re-import to pick up fresh env vars
# import importlib
# import main_toolbox
# importlib.reload(main_toolbox)
# main_toolbox.main()
